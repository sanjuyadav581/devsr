# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_excel('/content/Walmart_Dataset Python_Final_Assessment.xlsx')
df.info()# using this came to know all datatype and count of non null values of all columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3203 entries, 0 to 3202
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      3203 non-null   object
#  1   Order Date    3203 non-null   datetime64[ns]
#  2   Ship Date     3203 non-null   datetime64[ns]
#  3   EmailID       3203 non-null   object
#  4   Geography     3203 non-null   object
#  5   Category      3203 non-null   object
#  6   Product Name  3203 non-null   object
#  7   Sales         3203 non-null   float64
#  8   Quantity      3203 non-null   int64
#  9   Profit        3203 non-null   float64
# dtypes: datetime64[ns](2), float64(2), int64(1), object(5)
# memory usage: 250.4+ KB

# %%
df
# Out:
#             Order ID Order Date  Ship Date                   EmailID  \
# 0     CA-2013-138688 2013-06-13 2013-06-17   DarrinVanHuff@gmail.com
# 1     CA-2011-115812 2011-06-09 2011-06-14  BrosinaHoffman@gmail.com
# 2     CA-2011-115812 2011-06-09 2011-06-14  BrosinaHoffman@gmail.com
# 3     CA-2011-115812 2011-06-09 2011-06-14  BrosinaHoffman@gmail.com
# 4     CA-2011-115812 2011-06-09 2011-06-14  BrosinaHoffman@gmail.com
# ...              ...        ...        ...                       ...
# 3198  CA-2013-125794 2013-09-30 2013-10-04     MarisLaWare@gmail.com
# 3199  CA-2014-121258 2014-02-27 2014-03-04      DaveBrooks@gmail.com
# 3200  CA-2014-121258 2014-02-27 2014-03-04      DaveBrooks@gmail.com
# 3201  CA-2014-121258 2014-02-27 2014-03-04      DaveBrooks@gmail.com
# 3202  CA-2014-119914 2014-05-05 2014-05-10     ChrisCortes@gmail.com
#
#                                  Geography     Category  \
# 0     United States,Los Angeles,California       Labels
# 1     United States,Los Angeles,California  Furnishings
# 2     United States,Los Angeles,California          Art
# 3     United States,Los Angeles,California       Phones
# 4     United States,Los Angeles,California      Binders
# ...                                    ...          ...
# 3198  United States,Los Angeles,California  Accessories
# 3199   United States,Costa Mesa,California  Furnishings
# 3200   United States,Costa Mesa,California       Phones
# 3201   United States,Costa Mesa,California        Paper
# 3202  United States,Westminster,California   Appliances
#
#                                            Product Name    Sales  Quantity  \
# 0     Self-Adhesive Address Labels for Typewriters b...   14.620         2
# 1     Eldon Expressions Wood and Plastic Desk Access...   48.860         7
# 2                                            Newell 322    7.280         4
# 3                        Mitel 5320 IP Phone VoIP phone  907.152         4
# 4     DXL Angle-View Binders with Locking Rings by S...   18.504         3
# ...                                                 ...      ...       ...
# 3198  Memorex Mini Travel Drive 64 GB USB 2.0 Flash ...   36.240         1
# 3199  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.960         2
# 3200                              Aastra 57i VoIP phone  258.576         2
# 3201  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600         4
# 3202  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160         2
#
#        Profit
# 0      6.8714
# 1     14.1694
# 2      1.9656
# 3     90.7152
# 4      5.7825
# ...       ...
# 3198  15.2208
# 3199  15.6332
# 3200  19.3932
# 3201  13.3200
# 3202  72.9480
#
# [3203 rows x 10 columns]

# %%
df.describe()
# Out:
#               Sales     Quantity       Profit
# count   3203.000000  3203.000000  3203.000000
# mean     226.493233     3.828910    33.849032
# std      524.876877     2.260947   174.109081
# min        0.990000     1.000000 -3399.980000
# 25%       19.440000     2.000000     3.852000
# 50%       60.840000     3.000000    11.166400
# 75%      215.809000     5.000000    33.000400
# max    13999.960000    14.000000  6719.980800

# %%
df['Order ID'].value_counts()#length of rows
# Out:
# CA-2013-165330    11
# CA-2011-106439     9
# CA-2012-104346     9
# CA-2012-164882     9
# CA-2014-117457     9
#                   ..
# CA-2014-123701     1
# US-2011-167262     1
# CA-2014-108091     1
# CA-2012-144722     1
# CA-2014-119914     1
# Name: Order ID, Length: 1611, dtype: int64

# %%
df['Category'].value_counts()
# Out:
# Binders        471
# Paper          450
# Furnishings    304
# Phones         277
# Storage        266
# Accessories    258
# Art            250
# Chairs         207
# Appliances     136
# Labels         116
# Tables         116
# Bookcases       80
# Fasteners       72
# Supplies        69
# Envelopes       67
# Machines        39
# Copiers         25
# Name: Category, dtype: int64

# %%
df['Geography'].value_counts()#90% are from LA, SF and Seattle i think so lets see in future analysis
# Out:
# United States,Los Angeles,California       747
# United States,San Francisco,California     510
# United States,Seattle,Washington           428
# United States,San Diego,California         170
# United States,Phoenix,Arizona               63
#                                           ...
# United States,San Mateo,California           1
# United States,Redding,California             1
# United States,Yucaipa,California             1
# United States,Citrus Heights,California      1
# United States,Ontario,California             1
# Name: Geography, Length: 170, dtype: int64

# %%
number_of_cols= len(df.columns)
number_of_cols
# Out:
# 10

# %%
num_of_rows=df.shape[0]
num_of_rows#this can include duplicates
# Out:
# 3203

# %%
no_dup= df.drop_duplicates()
print(no_dup.shape[0])#so no duplicate rows found
# Out:
# 3203

# %%
missing= df.isna().sum()
missing #so no missing values found so we are good to go
# Out:
# Order ID        0
# Order Date      0
# Ship Date       0
# EmailID         0
# Geography       0
# Category        0
# Product Name    0
# Sales           0
# Quantity        0
# Profit          0
# dtype: int64

# %%
df_num= df[['Sales','Quantity','Profit']]
df_num # these are the 3 columns with numerical data
# Out:
#         Sales  Quantity   Profit
# 0      14.620         2   6.8714
# 1      48.860         7  14.1694
# 2       7.280         4   1.9656
# 3     907.152         4  90.7152
# 4      18.504         3   5.7825
# ...       ...       ...      ...
# 3198   36.240         1  15.2208
# 3199   91.960         2  15.6332
# 3200  258.576         2  19.3932
# 3201   29.600         4  13.3200
# 3202  243.160         2  72.9480
#
# [3203 rows x 3 columns]

# %%
print('Average sales done :',round(df_num['Sales'].mean(),2))
print('Average quantity sold :',round(df_num['Quantity'].mean(),0))
print('Average profit made :',round(df_num['Profit'].mean(),2))
# Out:
# Average sales done : 226.49
# Average quantity sold : 4.0
# Average profit made : 33.85

# %%
# Splitting the 'Geography' column into three separate columns for country, state, and city
df[['Country', 'State', 'City']] = df['Geography'].str.split(',', expand=True)
df
# Out:
#             Order ID Order Date  Ship Date                   EmailID  \
# 0     CA-2013-138688 2013-06-13 2013-06-17   DarrinVanHuff@gmail.com
# 1     CA-2011-115812 2011-06-09 2011-06-14  BrosinaHoffman@gmail.com
# 2     CA-2011-115812 2011-06-09 2011-06-14  BrosinaHoffman@gmail.com
# 3     CA-2011-115812 2011-06-09 2011-06-14  BrosinaHoffman@gmail.com
# 4     CA-2011-115812 2011-06-09 2011-06-14  BrosinaHoffman@gmail.com
# ...              ...        ...        ...                       ...
# 3198  CA-2013-125794 2013-09-30 2013-10-04     MarisLaWare@gmail.com
# 3199  CA-2014-121258 2014-02-27 2014-03-04      DaveBrooks@gmail.com
# 3200  CA-2014-121258 2014-02-27 2014-03-04      DaveBrooks@gmail.com
# 3201  CA-2014-121258 2014-02-27 2014-03-04      DaveBrooks@gmail.com
# 3202  CA-2014-119914 2014-05-05 2014-05-10     ChrisCortes@gmail.com
#
#                                  Geography     Category  \
# 0     United States,Los Angeles,California       Labels
# 1     United States,Los Angeles,California  Furnishings
# 2     United States,Los Angeles,California          Art
# 3     United States,Los Angeles,California       Phones
# 4     United States,Los Angeles,California      Binders
# ...                                    ...          ...
# 3198  United States,Los Angeles,California  Accessories
# 3199   United States,Costa Mesa,California  Furnishings
# 3200   United States,Costa Mesa,California       Phones
# 3201   United States,Costa Mesa,California        Paper
# 3202  United States,Westminster,California   Appliances
#
#                                            Product Name    Sales  Quantity  \
# 0     Self-Adhesive Address Labels for Typewriters b...   14.620         2
# 1     Eldon Expressions Wood and Plastic Desk Access...   48.860         7
# 2                                            Newell 322    7.280         4
# 3                        Mitel 5320 IP Phone VoIP phone  907.152         4
# 4     DXL Angle-View Binders with Locking Rings by S...   18.504         3
# ...                                                 ...      ...       ...
# 3198  Memorex Mini Travel Drive 64 GB USB 2.0 Flash ...   36.240         1
# 3199  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.960         2
# 3200                              Aastra 57i VoIP phone  258.576         2
# 3201  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600         4
# 3202  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160         2
#
#        Profit        Country        State        City
# 0      6.8714  United States  Los Angeles  California
# 1     14.1694  United States  Los Angeles  California
# 2      1.9656  United States  Los Angeles  California
# 3     90.7152  United States  Los Angeles  California
# 4      5.7825  United States  Los Angeles  California
# ...       ...            ...          ...         ...
# 3198  15.2208  United States  Los Angeles  California
# 3199  15.6332  United States   Costa Mesa  California
# 3200  19.3932  United States   Costa Mesa  California
# 3201  13.3200  United States   Costa Mesa  California
# 3202  72.9480  United States  Westminster  California
#
# [3203 rows x 13 columns]

# %%
days_diff = []
for i in range(len(df)):
    day = int((df["Ship Date"][i] - df["Order Date"][i]).days)
    days_diff.append(day)
#here we are counting how much time it takes to deliver a package
# days_diff.count(0)
# days_diff.count(1)
days_diff.count(2)
# Out:
# 450

# %%
data = df.assign(Days_Difference = days_diff)
data.head()
# Out:
#          Order ID Order Date  Ship Date                   EmailID  \
# 0  CA-2013-138688 2013-06-13 2013-06-17   DarrinVanHuff@gmail.com
# 1  CA-2011-115812 2011-06-09 2011-06-14  BrosinaHoffman@gmail.com
# 2  CA-2011-115812 2011-06-09 2011-06-14  BrosinaHoffman@gmail.com
# 3  CA-2011-115812 2011-06-09 2011-06-14  BrosinaHoffman@gmail.com
# 4  CA-2011-115812 2011-06-09 2011-06-14  BrosinaHoffman@gmail.com
#
#                               Geography     Category  \
# 0  United States,Los Angeles,California       Labels
# 1  United States,Los Angeles,California  Furnishings
# 2  United States,Los Angeles,California          Art
# 3  United States,Los Angeles,California       Phones
# 4  United States,Los Angeles,California      Binders
#
#                                         Product Name    Sales  Quantity  \
# 0  Self-Adhesive Address Labels for Typewriters b...   14.620         2
# 1  Eldon Expressions Wood and Plastic Desk Access...   48.860         7
# 2                                         Newell 322    7.280         4
# 3                     Mitel 5320 IP Phone VoIP phone  907.152         4
# 4  DXL Angle-View Binders with Locking Rings by S...   18.504         3
#
#     Profit        Country        State        City  Days_Difference
# 0   6.8714  United States  Los Angeles  California                4
# 1  14.1694  United States  Los Angeles  California                5
# 2   1.9656  United States  Los Angeles  California                5
# 3  90.7152  United States  Los Angeles  California                5
# 4   5.7825  United States  Los Angeles  California                5

# %%
temp=data.groupby(['Category','Days_Difference']).size()
temp
# Out:
# Category     Days_Difference
# Accessories  0                  13
#              1                  10
#              2                  36
#              3                  30
#              4                  61
#                                 ..
# Tables       3                  10
#              4                  29
#              5                  25
#              6                  12
#              7                  10
# Length: 136, dtype: int64

# %%
df[data['Days_Difference']>5] #there are 599 orders where it took more than 5 days to deliver the order
# Out:
#             Order ID Order Date  Ship Date                 EmailID  \
# 17    CA-2012-135545 2012-11-24 2012-11-30   KunstMiller@gmail.com
# 18    CA-2012-135545 2012-11-24 2012-11-30   KunstMiller@gmail.com
# 19    CA-2012-135545 2012-11-24 2012-11-30   KunstMiller@gmail.com
# 20    CA-2012-135545 2012-11-24 2012-11-30   KunstMiller@gmail.com
# 28    US-2014-109484 2014-11-07 2014-11-13   RogerBarcio@gmail.com
# ...              ...        ...        ...                     ...
# 3154  US-2013-125402 2013-09-26 2013-10-02     DanLawera@gmail.com
# 3158  CA-2011-142979 2011-04-12 2011-04-18   EdwardHooks@gmail.com
# 3182  CA-2014-164028 2014-11-25 2014-12-01       JohnLee@gmail.com
# 3183  CA-2011-143371 2011-12-28 2012-01-03  MaribethDona@gmail.com
# 3184  CA-2011-143371 2011-12-28 2012-01-03  MaribethDona@gmail.com
#
#                                    Geography     Category  \
# 17      United States,Los Angeles,California  Accessories
# 18      United States,Los Angeles,California      Binders
# 19      United States,Los Angeles,California        Paper
# 20      United States,Los Angeles,California  Furnishings
# 28             United States,Portland,Oregon      Binders
# ...                                      ...          ...
# 3154     United States,Long Beach,California       Chairs
# 3158           United States,Lodi,California          Art
# 3182  United States,San Francisco,California  Accessories
# 3183        United States,Anaheim,California      Storage
# 3184        United States,Anaheim,California     Supplies
#
#                                            Product Name    Sales  Quantity  \
# 17    Verbatim 25 GB 6x Blu-ray Single Layer Recorda...   13.980         2
# 18    Acco PRESSTEX Data Binder with Storage Hooks, ...   25.824         6
# 19                                           Xerox 1943  146.730         3
# 20                          Luxo Economy Swing Arm Lamp   79.760         4
# 28    Flexible Leather- Look Classic Collection Ring...    5.682         1
# ...                                                 ...      ...       ...
# 3154      Global Airflow Leather Mesh Back Chair, Black  483.136         4
# 3158                       Prismacolor Color Pencil Set   39.680         2
# 3182  Memorex Mini Travel Drive 16 GB USB 2.0 Flash ...  223.580        14
# 3183        Carina Mini System Audio Rack, Model AR050B  998.820         9
# 3184                           Acme Box Cutter Scissors   51.150         5
#
#        Profit        Country          State        City
# 17     6.1512  United States    Los Angeles  California
# 18     9.3612  United States    Los Angeles  California
# 19    68.9631  United States    Los Angeles  California
# 20    22.3328  United States    Los Angeles  California
# 28    -3.7880  United States       Portland      Oregon
# ...       ...            ...            ...         ...
# 3154  60.3920  United States     Long Beach  California
# 3158  16.2688  United States           Lodi  California
# 3182  87.1962  United States  San Francisco  California
# 3183  29.9646  United States        Anaheim  California
# 3184  13.2990  United States        Anaheim  California
#
# [599 rows x 13 columns]

# %%
data[data['Days_Difference']>5]["Category"].value_counts().plot(kind='bar',figsize=(10,10),
                     title= "Categorywise Product taking more than 5 days for ordering to shipping",
                                                                xlabel='Product Category',ylabel='Num_of_orders')
# Out:
# <Axes: title={'center': 'Categorywise Product taking more than 5 days for ordering to shipping'}, xlabel='Product Category', ylabel='Num_of_orders'>

# %%
#from the above graph, binders and paper type products took more than 5 days to deliver
# but we should also keep in mind that most of the data are from 2 categories, binders and papers so we can't be sure.

# %%
data[data['Days_Difference']>5]["Geography"].str.split(",").str[-1].value_counts().plot(kind='bar',
                                figsize=(10,10),title= "Geographywise Products taking more than 5 days for ordering to shipping",
                                            xlabel='City',ylabel='Num_of_orders')
# Out:
# <Axes: title={'center': 'Geographywise Products taking more than 5 days for ordering to shipping'}, xlabel='City', ylabel='Num_of_orders'>

# %%
data.groupby('City')['Sales'].sum().plot(kind="pie",figsize=(10,10),title= "Geographywise Sales",autopct='%1.0f%%')
# Out:
# <Axes: title={'center': 'Geographywise Sales'}, ylabel='Sales'>

# %%
data.groupby('Category')['Sales'].sum().plot(kind="pie",figsize=(10,10),title= "Categorywise Sales",autopct='%1.0f%%')
# Out:
# <Axes: title={'center': 'Categorywise Sales'}, ylabel='Sales'>

# %%
df_num['Days_Difference']=data['Days_Difference']
df_num
# Out:
# <ipython-input-98-4c83ea615809>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_num['Days_Difference']=data['Days_Difference']
#         Sales  Quantity   Profit  Days_Difference
# 0      14.620         2   6.8714                4
# 1      48.860         7  14.1694                5
# 2       7.280         4   1.9656                5
# 3     907.152         4  90.7152                5
# 4      18.504         3   5.7825                5
# ...       ...       ...      ...              ...
# 3198   36.240         1  15.2208                4
# 3199   91.960         2  15.6332                5
# 3200  258.576         2  19.3932                5
# 3201   29.600         4  13.3200                5
# 3202  243.160         2  72.9480                5
#
# [3203 rows x 4 columns]

# %%
corr_matrix=df_num.corr()
corr_matrix
#we can clearly know that Sales and profit are somehow correlated
# Out:
#                     Sales  Quantity    Profit  Days_Difference
# Sales            1.000000  0.214665  0.647477        -0.019958
# Quantity         0.214665  1.000000  0.093240         0.047754
# Profit           0.647477  0.093240  1.000000        -0.028638
# Days_Difference -0.019958  0.047754 -0.028638         1.000000

# %%
#For correlation map
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
df['Country'].value_counts() #so all are from US so we maynot need this column
# Out:
# United States    3203
# Name: Country, dtype: int64

# %%
df['State'].value_counts() #there are 169 states there can be some wrong info in it
# Out:
# Los Angeles       747
# San Francisco     510
# Seattle           428
# San Diego         170
# Phoenix            63
#                  ...
# Cheyenne            1
# Yucaipa             1
# Redding             1
# Citrus Heights      1
# Layton              1
# Name: State, Length: 169, dtype: int64

# %%
df['City'].value_counts()
# Out:
# California    2001
# Washington     506
# Arizona        224
# Colorado       182
# Oregon         124
# Utah            53
# Nevada          39
# New Mexico      37
# Idaho           21
# Montana         15
# Wyoming          1
# Name: City, dtype: int64

# %%
ex1=df[['Sales','State','City']]
ex1
# Out:
#         Sales        State        City
# 0      14.620  Los Angeles  California
# 1      48.860  Los Angeles  California
# 2       7.280  Los Angeles  California
# 3     907.152  Los Angeles  California
# 4      18.504  Los Angeles  California
# ...       ...          ...         ...
# 3198   36.240  Los Angeles  California
# 3199   91.960   Costa Mesa  California
# 3200  258.576   Costa Mesa  California
# 3201   29.600   Costa Mesa  California
# 3202  243.160  Westminster  California
#
# [3203 rows x 3 columns]

# %%
ex1['Days_Difference']=data['Days_Difference']
ex1
# Out:
# <ipython-input-105-e220b8d4e96d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ex1['Days_Difference']=data['Days_Difference']
#         Sales        State        City  Days_Difference
# 0      14.620  Los Angeles  California                4
# 1      48.860  Los Angeles  California                5
# 2       7.280  Los Angeles  California                5
# 3     907.152  Los Angeles  California                5
# 4      18.504  Los Angeles  California                5
# ...       ...          ...         ...              ...
# 3198   36.240  Los Angeles  California                4
# 3199   91.960   Costa Mesa  California                5
# 3200  258.576   Costa Mesa  California                5
# 3201   29.600   Costa Mesa  California                5
# 3202  243.160  Westminster  California                5
#
# [3203 rows x 4 columns]

# %%
# ex1[].groupby('State')['Days_Difference'].mean().sort_values(ascending=False)

# %%
data.groupby('City')['Profit'].sum()
#as there are negetive values so lets use bar chart
# Out:
# City
# Arizona       -3427.9246
# California    76381.3871
# Colorado      -6527.8579
# Idaho           826.7231
# Montana        1833.3285
# Nevada         3316.7659
# New Mexico     1157.1161
# Oregon        -1190.4705
# Utah           2546.5335
# Washington    33402.6517
# Wyoming         100.1960
# Name: Profit, dtype: float64

# %%
fig = plt.figure(figsize = (15, 10))
plt.bar(data.groupby('City')['Profit'].sum().keys(),data.groupby('City')['Profit'].sum(),edgecolor="red")
# Out:
# <BarContainer object of 11 artists>

# %%
#for categorywise profit
fig = plt.figure(figsize = (20, 12))
plt.bar(data.groupby('Category')['Profit'].sum().keys(),data.groupby('Category')['Profit'].sum(),color="darkgreen",edgecolor="darkgreen")
# Out:
# <BarContainer object of 17 artists>

# %%
# Trend Analysis

import matplotlib.pyplot as plt


df['Year'] = df['Order Date'].dt.year


yearly_data = df.groupby('Year').agg({'Sales': 'sum', 'Profit': 'sum'}).reset_index()


plt.figure(figsize=(10, 6))
plt.plot(yearly_data['Year'], yearly_data['Sales'], label='Total Sales', marker='o')
plt.plot(yearly_data['Year'], yearly_data['Profit'], label='Total Profit', marker='o')
plt.xlabel('Year')
plt.ylabel('Amount')
plt.title('Sales and Profit Trends Over the Years')
plt.legend()
plt.grid(True)
plt.show()

# %%
category_sales = df.groupby('Category')['Sales'].sum().sort_values(ascending=False)
most_growth_category = category_sales.idxmax()
print("Product category with the most growth in sales over the years:", most_growth_category)
print('\n\n')

# Customer Analysis
top_customers_orders = df.groupby('EmailID')['Order ID'].count().nlargest(5)
top_customers_sales = df.groupby('EmailID')['Sales'].sum().nlargest(5)
print("Top 5 customers based on the number of orders placed:")
print(top_customers_orders)
print("\nTop 5 customers based on total sales generated:")
print(top_customers_sales)
# Out:
# Product category with the most growth in sales over the years: Chairs
#
#
#
# Top 5 customers based on the number of orders placed:
# EmailID
# WilliamBrown@gmail.com     24
# ArthurPrichep@gmail.com    23
# RickWilson@gmail.com       19
# GregGuthrie@gmail.com      17
# DarrinSayre@gmail.com      16
# Name: Order ID, dtype: int64
#
# Top 5 customers based on total sales generated:
# EmailID
# RaymondBuch@gmail.com      14345.276
# KenLonsdale@gmail.com       8472.394
# EdwardHooks@gmail.com       7447.770
# JaneWaco@gmail.com          7391.530
# KarenFerguson@gmail.com     7182.766
# Name: Sales, dtype: float64

# %%
# Insights:
# - From the trend analysis, it can be observed that both sales and profit have shown an increasing trend over the years, with some fluctuations.
# - The product category with the most growth in sales over the years is determined.
# - The top 5 customers based on the number of orders placed and total sales generated are identified, indicating their importance to the business.
# - Repeat purchase behavior can be analyzed by calculating the average time between orders for each customer,
#    which provides insights into customer loyalty and retention strategies.

# %%
#Comprehensive Analytics:

# %%
# Comprehensive Analytics:
# i. What strategies can be implemented to optimize the supply chain, based on insights from sales velocity and order fulfillment data?
# ii. What underlying factors contribute to the geographic distribution of sales and how can these insights inform targeted marketing strategies?
# iii. Can you identify patterns or predictors of high-value customers, and how can we leverage this information to enhance customer loyalty and acquisition strategies?
