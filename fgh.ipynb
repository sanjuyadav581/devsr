# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8, 11, 2, 10,1])
ypoints = np.array([3, 10, 3,7,8,3])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y1points = np.array([3, 8, 1, 10, 5, 7])
y2points = np.array([5, 5, 1, 1, 15, 7])


plt.plot(y1points,marker = 'H')
plt.plot(y2points,marker = 'H')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([0, 1])
y = np.array([3, 0])

plt.subplot(2, 2, 1)
plt.plot(x,y)
x = np.array([0, 2])
y = np.array([10, 20])

plt.subplot(2, 2, 2)
plt.plot(x,y)

plt.show()

#plot 3:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 2, 3)
plt.plot(x,y)

plt.show()

#plot 3:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 2, 4)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D", "e", "f", "g"])
y = np.array([3, 81, 110, 10,150,56,7])

plt.barh(x,y, height = 0.1)
plt.show()

# %%
x = ["APPLES", "BANANAS"]
y = [400, 350]
plt.bar(x, y)
# Out:
# <BarContainer object of 2 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
# !pip install mysql-connector-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 36.5 MB/s eta 0:00:00
# ...

# %%
import mysql.connector

# %%
def fetch_customer_churn():
    try:
        connection = mysql.connector.connect(
            host="34.30.129.74",
            user="root",
            password="01012001",
            database="lva"
        )

        if connection.is_connected():
            query = "SELECT * FROM customer_churn WHERE state = 'KS' AND churn LIKE 'True%'"
            cursor = connection.cursor()
            cursor.execute(query)
            records = cursor.fetchall()
            for record in records:
                print(record)
            cursor.close()
            connection.close()

            return "Success"

    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_BAD_TABLE_ERROR:
            print("Table does not exist.")
            return "Failure"
        else:
            print("MySQL error:", err)
            return "Failure"
result = fetch_customer_churn()
print("Result:", result)
# Out:
# ('KS', 92, 408, '386-4170', 'yes', 'no', 0, 62.6, 111, 10.64, 180.6, 126, 15.35, 221.7, 80, 9.98, 10.4, 2, 2.81, 1, 'TRUE\r')
# ('KS', 46, 510, '365-5979', 'no', 'no', 0, 250.3, 100, 42.55, 260.6, 90, 22.15, 195.0, 104, 8.78, 13.3, 2, 3.59, 2, 'TRUE\r')
# ('KS', 110, 415, '383-1657', 'yes', 'no', 0, 293.3, 79, 49.86, 188.5, 90, 16.02, 266.9, 91, 12.01, 14.5, 4, 3.92, 0, 'TRUE\r')
# ('KS', 110, 415, '369-8024', 'yes', 'yes', 27, 267.9, 103, 45.54, 263.3, 74, 22.38, 178.1, 106, 8.01, 8.3, 2, 2.24, 1, 'TRUE\r')
# ('KS', 167, 415, '409-4734', 'no', 'no', 0, 131.6, 120, 22.37, 211.3, 96, 17.96, 168.3, 97, 7.57, 11.1, 4, 3.0, 4, 'TRUE\r')
# ('KS', 24, 510, '369-5449', 'no', 'no', 0, 243.0, 91, 41.31, 183.9, 77, 15.63, 184.3, 109, 8.29, 15.3, 6, 4.13, 0, 'TRUE\r')
# ('KS', 126, 408, '379-8681', 'no', 'no', 0, 321.3, 99, 54.62, 167.9, 93, 14.27, 193.6, 106, 8.71, 8.0, 4, 2.16, 1, 'TRUE\r')
# ...
